# %%
import numpy as np 
import pandas as pd 
from bs4 import BeautifulSoup
import requests

# %%
# THIS IS THE FIRST PART OF QUESTIONS
data = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M', index_col=0)

# %%
source = requests.get('https://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&oldid=945633050').text
soup = BeautifulSoup(source, 'lxml')

# %%
class Scrapy:
       
        def parse_url(self, url):
            response = requests.get(url)
            soup = BeautifulSoup(response.text, 'lxml')
            return [(self.parse_html_table(table))\
                    for table in soup.find_all('table', class_="wikitable sortable")]  
    
        def parse_html_table(self, table):
            n_columns = 0
            n_rows=0
            column_names = []
            for row in table.find_all('tr'):
                td_tags = row.find_all('td')
                if len(td_tags) > 0:
                    n_rows+=1
                    if n_columns == 0:
                        n_columns = len(td_tags)
                        
                th_tags = row.find_all('th') 
                if len(th_tags) > 0 and len(column_names) == 0:
                    for th in th_tags:
                        column_names.append(th.get_text())
    
            if len(column_names) > 0 and len(column_names) != n_columns:
                raise Exception("Column titles do not match the number of columns")
    
            columns = column_names if len(column_names) > 0 else range(0,n_columns)
            df = pd.DataFrame(columns = columns,
                              index= range(0,n_rows))
            row_marker = 0
            for row in table.find_all('tr'):
                column_marker = 0
                columns = row.find_all('td')
                for column in columns:
                    df.iat[row_marker,column_marker] = column.get_text()
                    column_marker += 1
                if len(columns) > 0:
                    row_marker += 1
                    
            for col in df:
                try:
                    df[col] = df[col].astype(float)
                except ValueError:
                    pass
            
            return df

# %%
url = 'https://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&oldid=945633050'
hp = Scrapy()
table = hp.parse_url(url)[0] 
table.head(10)
# Out:
#   Postcode           Borough     Neighbourhood\n
# 0      M1A      Not assigned      Not assigned\n
# 1      M2A      Not assigned      Not assigned\n
# 2      M3A        North York         Parkwoods\n
# 3      M4A        North York  Victoria Village\n
# 4      M5A  Downtown Toronto      Harbourfront\n
# 5      M6A        North York  Lawrence Heights\n
# 6      M6A        North York    Lawrence Manor\n
# 7      M7A  Downtown Toronto      Queen's Park\n
# 8      M8A      Not assigned      Not assigned\n
# 9      M9A         Etobicoke  Islington Avenue\n

# %%
#not assigned has to be removed
table = table[table.Borough != 'Not assigned']
table = table.replace('\n',' ', regex=True)
table = table[table['Neighbourhood\n'] != 'Not assigned']
table.head(10)
# Out:
#    Postcode           Borough    Neighbourhood\n
# 2       M3A        North York         Parkwoods
# 3       M4A        North York  Victoria Village
# 4       M5A  Downtown Toronto      Harbourfront
# 5       M6A        North York  Lawrence Heights
# 6       M6A        North York    Lawrence Manor
# 7       M7A  Downtown Toronto      Queen's Park
# 9       M9A         Etobicoke  Islington Avenue
# 10      M1B       Scarborough             Rouge
# 11      M1B       Scarborough           Malvern
# 13      M3B        North York   Don Mills North

# %%
#GROUPBY postcode and hoods
df = table.groupby(['Postcode','Borough'])['Neighbourhood\n'].apply(lambda x: ", ".join(x.astype(str))).reset_index()
df = df.sample(frac=1).reset_index(drop=True)

# %%
print(df.shape)
print(df)
# Out:
# (103, 3)
#     Postcode           Borough  \
# 0        M6R      West Toronto
# 1        M6K      West Toronto
# 2        M1W       Scarborough
# 3        M9M        North York
# 4        M6G  Downtown Toronto
# 5        M4K      East Toronto
# 6        M5J  Downtown Toronto
# 7        M3H        North York
# 8        M3K        North York
# 9        M1C       Scarborough
# 10       M3B        North York
# 11       M1J       Scarborough
# 12       M5S  Downtown Toronto
# 13       M9W         Etobicoke
# 14       M6C              York
# 15       M1H       Scarborough
# 16       M4B         East York
# 17       M6H      West Toronto
# 18       M4A        North York
# 19       M9P         Etobicoke
# 20       M1E       Scarborough
# 21       M4Y  Downtown Toronto
# 22       M9C         Etobicoke
# 23       M8W         Etobicoke
# 24       M1G       Scarborough
# 25       M5P   Central Toronto
# 26       M4G         East York
# 27       M5H  Downtown Toronto
# 28       M1N       Scarborough
# 29       M4H         East York
# ..       ...               ...
# 73       M5A  Downtown Toronto
# 74       M6A        North York
# 75       M9N              York
# 76       M6J      West Toronto
# 77       M7A  Downtown Toronto
# 78       M9L        North York
# 79       M8Z         Etobicoke
# 80       M5X  Downtown Toronto
# 81       M1M       Scarborough
# 82       M7R       Mississauga
# 83       M6B        North York
# 84       M6E              York
# 85       M5K  Downtown Toronto
# 86       M7Y      East Toronto
# 87       M5L  Downtown Toronto
# 88       M4S   Central Toronto
# 89       M5C  Downtown Toronto
# 90       M6P      West Toronto
# 91       M5E  Downtown Toronto
# 92       M4V   Central Toronto
# 93       M9A         Etobicoke
# 94       M2L        North York
# 95       M3J        North York
# 96       M4L      East Toronto
# 97       M6L        North York
# 98       M4J         East York
# 99       M2J        North York
# 100      M5T  Downtown Toronto
# 101      M4R   Central Toronto
# 102      M1X       Scarborough
#
#                                        Neighbourhood\n
# 0                             Parkdale , Roncesvalles
# 1      Brockton , Exhibition Place , Parkdale Village
# 2                                     L'Amoreaux West
# 3                                   Emery , Humberlea
# 4                                            Christie
# 5                       The Danforth West , Riverdale
# 6    Harbourfront East , Toronto Islands , Union St...
# 7    Bathurst Manor , Downsview North , Wilson Heig...
# 8                        CFB Toronto , Downsview East
# 9            Highland Creek , Rouge Hill , Port Union
# 10                                    Don Mills North
# 11                                Scarborough Village
# 12                    Harbord , University of Toronto
# 13                                          Northwest
# 14                                 Humewood-Cedarvale
# 15                                          Cedarbrae
# 16                   Woodbine Gardens , Parkview Hill
# 17                      Dovercourt Village , Dufferin
# 18                                   Victoria Village
# 19                                          Westmount
# 20                Guildwood , Morningside , West Hill
# 21                               Church and Wellesley
# 22   Bloordale Gardens , Eringate , Markland Wood ,...
# 23                            Alderwood , Long Branch
# 24                                             Woburn
# 25               Forest Hill North , Forest Hill West
# 26                                            Leaside
# 27                         Adelaide , King , Richmond
# 28                       Birch Cliff , Cliffside West
# 29                                   Thorncliffe Park
# ..                                                 ...
# 73                                       Harbourfront
# 74                  Lawrence Heights , Lawrence Manor
# 75                                             Weston
# 76                          Little Portugal , Trinity
# 77                                       Queen's Park
# 78                                      Humber Summit
# 79   Kingsway Park South West , Mimico NW , The Que...
# 80            First Canadian Place , Underground city
# 81   Cliffcrest , Cliffside , Scarborough Village W...
# 82              Canada Post Gateway Processing Centre
# 83                                          Glencairn
# 84                                Caledonia-Fairbanks
# 85          Design Exchange , Toronto Dominion Centre
# 86   Business Reply Mail Processing Centre 969 East...
# 87                    Commerce Court , Victoria Hotel
# 88                                         Davisville
# 89                                     St. James Town
# 90                     High Park , The Junction South
# 91                                        Berczy Park
# 92   Deer Park , Forest Hill SE , Rathnelly , South...
# 93                                   Islington Avenue
# 94                          Silver Hills , York Mills
# 95                   Northwood Park , York University
# 96                    The Beaches West , India Bazaar
# 97               Downsview , North Park , Upwood Park
# 98                                       East Toronto
# 99                     Fairview , Henry Farm , Oriole
# 100       Chinatown , Grange Park , Kensington Market
# 101                                North Toronto West
# 102                                       Upper Rouge
#
# [103 rows x 3 columns]

# %%
#BEGIN THE SECOND QUESTION!!!!!
url1="http://cocl.us/Geospatial_data"
geo_data=pd.read_csv(url1)
geo_data.head(10)
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476
# 5         M1J  43.744734 -79.239476
# 6         M1K  43.727929 -79.262029
# 7         M1L  43.711112 -79.284577
# 8         M1M  43.716316 -79.239476
# 9         M1N  43.692657 -79.264848

# %%
full_table = df.set_index('Postcode').join(geo_data.set_index('Postal Code'))
full_table = full_table.sample(frac=1).reset_index(drop=True)
full_table.head(20)
# Out:
#              Borough                                    Neighbourhood\n  \
# 0        Scarborough  Agincourt North , L'Amoreaux East , Milliken ,...
# 1        Scarborough                      Birch Cliff , Cliffside West
# 2       West Toronto                         Little Portugal , Trinity
# 3    Central Toronto              Forest Hill North , Forest Hill West
# 4    Central Toronto                      Moore Park , Summerhill East
# 5          Etobicoke   The Kingsway , Montgomery Road , Old Mill North
# 6          Etobicoke                           Alderwood , Long Branch
# 7        Scarborough     East Birchmount Park , Ionview , Kennedy Park
# 8   Downtown Toronto                      Cabbagetown , St. James Town
# 9    Central Toronto                                North Toronto West
# 10  Downtown Toronto                        Adelaide , King , Richmond
# 11  Downtown Toronto                         Ryerson , Garden District
# 12  Downtown Toronto                                       Berczy Park
# 13      West Toronto                           Parkdale , Roncesvalles
# 14       Scarborough  Dorset Park , Scarborough Town Centre , Wexfor...
# 15  Downtown Toronto  Harbourfront East , Toronto Islands , Union St...
# 16         East York                  Woodbine Gardens , Parkview Hill
# 17         Etobicoke  Cloverdale , Islington , Martin Grove , Prince...
# 18  Downtown Toronto                   Commerce Court , Victoria Hotel
# 19        North York                                         Glencairn
#
#      Latitude  Longitude
# 0   43.815252 -79.284577
# 1   43.692657 -79.264848
# 2   43.647927 -79.419750
# 3   43.696948 -79.411307
# 4   43.689574 -79.383160
# 5   43.653654 -79.506944
# 6   43.602414 -79.543484
# 7   43.727929 -79.262029
# 8   43.667967 -79.367675
# 9   43.715383 -79.405678
# 10  43.650571 -79.384568
# 11  43.657162 -79.378937
# 12  43.644771 -79.373306
# 13  43.648960 -79.456325
# 14  43.757410 -79.273304
# 15  43.640816 -79.381752
# 16  43.706397 -79.309937
# 17  43.650943 -79.554724
# 18  43.648198 -79.379817
# 19  43.709577 -79.445073

# %%
print(list(df))
print(list(geo_data))

full_table = df.set_index('Postcode').join(geo_data.set_index('Postal Code'))
full_table = full_table.sample(frac=1).reset_index(drop=True)
full_table.head(20)
# Out:
# ['Postcode', 'Borough', 'Neighbourhood\n']
# ['Postal Code', 'Latitude', 'Longitude']
#              Borough                                    Neighbourhood\n  \
# 0        Scarborough         Clarks Corners , Sullivan , Tam O'Shanter
# 1          East York                                  Woodbine Heights
# 2          Etobicoke                           Alderwood , Long Branch
# 3   Downtown Toronto                                      Harbourfront
# 4    Central Toronto                                     Lawrence Park
# 5         North York                 Lawrence Heights , Lawrence Manor
# 6        Mississauga             Canada Post Gateway Processing Centre
# 7        Scarborough                      Birch Cliff , Cliffside West
# 8          East York                                      East Toronto
# 9         North York                                 Emery , Humberlea
# 10      East Toronto                     The Danforth West , Riverdale
# 11       Scarborough     East Birchmount Park , Ionview , Kennedy Park
# 12  Downtown Toronto                                    St. James Town
# 13         Etobicoke                                         Westmount
# 14      West Toronto                           Parkdale , Roncesvalles
# 15              York                               Caledonia-Fairbanks
# 16         Etobicoke  Kingsview Village , Martin Grove Gardens , Ric...
# 17       Scarborough                 Clairlea , Golden Mile , Oakridge
# 18       Scarborough  Dorset Park , Scarborough Town Centre , Wexfor...
# 19        North York                                         Glencairn
#
#      Latitude  Longitude
# 0   43.781638 -79.304302
# 1   43.695344 -79.318389
# 2   43.602414 -79.543484
# 3   43.654260 -79.360636
# 4   43.728020 -79.388790
# 5   43.718518 -79.464763
# 6   43.636966 -79.615819
# 7   43.692657 -79.264848
# 8   43.685347 -79.338106
# 9   43.724766 -79.532242
# 10  43.679557 -79.352188
# 11  43.727929 -79.262029
# 12  43.651494 -79.375418
# 13  43.696319 -79.532242
# 14  43.648960 -79.456325
# 15  43.689026 -79.453512
# 16  43.688905 -79.554724
# 17  43.711112 -79.284577
# 18  43.757410 -79.273304
# 19  43.709577 -79.445073

# %%
#LAST AND FINAL PART!
#Explore and cluster the neighborhoods in Toronto.

# %%
from geopy.geocoders import Nominatim 
import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans

import folium

# %%
address = 'Toronto'
geolocator = Nominatim()
location = geolocator.geocode(address)
Latitude = 43.653963
Longitude = -79.387207
# Out:
# C:\Users\Marcello\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Using Nominatim with the default "geopy/1.21.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.

# %%
map_geo = folium.Map(location=[latitude, longitude], zoom_start=11)
for lat, lng, label in zip(full_table['Latitude'], full_table['Longitude'], full_table['Neighbourhood\n']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3,
        popup=label,
        color='black',
        fill=True,
        fill_color='black',
        fill_opacity=0.10,
        parse_html=False).add_to(map_geo)  
#click on each button on the map to see the hood you're looking at.
# Out:
# <folium.folium.Map object at 0x0000018B61085B38>

# %%
map_geo
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
